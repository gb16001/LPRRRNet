# %%
import train_net
train_net.train('args.yaml')

# %%
import train_net
train_net.evaluate('args.yaml')
# Out:
# Successful to build network!
# load pretrained model successful!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 import train_net
# ----> 2 train_net.evaluate('args.yaml')
#
# File ~/Desktop/LicenceRecognition/LPRNet_Pytorch/train_net.py:133, in evaluate(conf_file)
#     131 assert args.pretrained_model!= ''
#     132 init_net_weight(net,args)
# --> 133 Greedy_Decode_Eval(net,test_iter,args)
#     134 return
#
# File ~/Desktop/LicenceRecognition/LPRNet_Pytorch/train_net.py:271, in Greedy_Decode_Eval(Net, testIter, args)
#     269     targets =unpack_lables(labels,lengths)
#     270     # forward
# --> 271     prebs = Net(images)
#     272     Tp,Tn_1,Tn_2 =greedy_decode(prebs,targets,Tp,Tn_1,Tn_2)
#     274 Acc = Tp * 1.0 / (Tp + Tn_1 + Tn_2)
#
# ...
